# %%
import os
import sys
import math
import glob
import imp
import importlib
import socket
import time
import random
import numpy as np
import scipy
from scipy import sparse
from scipy.spatial.distance import cosine
import sklearn
from sklearn.metrics import pairwise_distances
import sklearn.decomposition
import matplotlib as mpl
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import HTML
import vsmlib
from myutils.formathelper import sizeof_fmt,countof_fmt
#from IPython.display import display, clear_output
from IPython.core import display
import PIL
from io import BytesIO
from PIL import Image
# %matplotlib inline
mpl.rcParams['figure.figsize'] = (17.5, 8.0)

# %%
def display_pil_image(im):
   """Displayhook function for PIL Images, rendered as PNG."""
   b = BytesIO()
   im.save(b, format='png')
   data = b.getvalue()
   ip_img = display.Image(data=data, format='png', embed=True)
   return ip_img._repr_png_()

png_formatter = get_ipython().display_formatter.formatters['image/png']
dpi = png_formatter.for_type(Image.Image, display_pil_image)

# %%
if socket.gethostname()=="cypress":  dir_root="/storage/scratch/brown"
if socket.gethostname()=="ashtree":  dir_root="/mnt/work/nlp_scratch/BNC_w1"
if socket.gethostname()=="rc017.m.gsic.titech.ac.jp":  dir_root="/home/blackbird/data/scratch/brown"
#imp.reload(vsmlib.model)

# %%
from matplotlib.colors import Normalize

class MidpointNormalize(Normalize):
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        #m=max(abs(vmin),abs(vmax))
        Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        # I'm ignoring masked values and all kinds of edge cases to make a
        # simple example...
        m=max(abs(self.vmin),abs(self.vmax))
        x, y =[-m, self.midpoint, m], [0, 0.5, 1]
        #x, y = [-20, self.midpoint, self.vmax], [0, 0.5, 1]
        return np.ma.masked_array(np.interp(value, x, y))
 
    
def plot_heat(ax,m,xlabels,ylabels):
    #norm = Normalize(-10,10,False)
    norm = MidpointNormalize(midpoint=0)
    ax.set_aspect('equal')
    plt.xticks(rotation=90)    
    ax.set_xticks(np.arange(m.shape[1])+0.5, minor=False)
    ax.set_yticks(np.arange(m.shape[0])+0.5, minor=False)
    ax.set_xticklabels(xlabels, minor=False)
    ax.set_yticklabels(ylabels, minor=False)
    for tic in ax.xaxis.get_major_ticks():
        tic.tick1On = tic.tick2On = False
    for tic in ax.yaxis.get_major_ticks():
        tic.tick1On = tic.tick2On = False
    #ax.set_frame_on(False)
    heatmap = plt.pcolor(np.array(m), norm=norm, cmap=mpl.cm.RdBu, edgecolors="black")    
#    heatmap = plt.pcolor(np.array(m), cmap=mpl.cm.RdBu, edgecolors="black")    
    #im = ax.imshow(np.array(m), norm=norm, cmap=plt.cm.seismic, interpolation='none')
#fig.colorbar(im)
    cb=plt.colorbar(heatmap,orientation='horizontal',shrink=1,aspect=40)
    #cb.fraction=0.1
    
def draw_features_and_similarity(mm):
    rows,cols,xlabels=mm.filter_submatrix(words_of_interest,25)
    ax=plt.subplot(1,2,1)
    plot_heat(ax,cols,xlabels,words_of_interest)
    #plot_heat(ax,abs(m),numbered)
    ax=plt.subplot(1,2,2)
    t = 1-pairwise_distances(rows, metric="cosine")
    np.fill_diagonal(t,0)
    plot_heat(ax,t,words_of_interest,words_of_interest)
    #plt.savefig("m1.pdf")

def draw_features(mm,num_features=20):
    rows,cols,xlabels=mm.filter_submatrix(words_of_interest,num_features)
    ax=plt.subplot()
    plot_heat(ax,cols,xlabels,words_of_interest)

# %%
#m=load_from_dir("/storage/scratch/brown_svd300")
m=vsmlib.model.load_from_dir("/mnt/work/nlp_scratch/BNC_w2//")
#m=vsmlib.model.load_from_dir("/storage/scratch/_w2v")
# Out:
# this is sparse explicit
# Matrix loaded in 0.20 sec
# Matrix dimentions : (64661, 64661) (64.7K unique words in the corpus )
# Would take 15.6GiB if stored in dense format
# Cnt nonzero elements = 33450690 (should take about 127.6MiB of memory space
# Sparsity = 0.8001%

# %%
#m.clip_negatives()
#m.normalize()
print(m.name)
print(m.provenance)
#m.vocabulary.lst_words
# Out:
# explicit_BNC_w2_normalized
# source corpus : /mnt/storage/Data/Corpora/raw_texts/BNC/
# words in corpus : 49265119
# unique words : 342548
# minimal frequency: 20
# unique words : 64661
# windows size : 2
# frequency weightening : PMI
# transform : normalize

# %%
#words_of_interest=["germany","berlin","japan","tokyo"]
words_of_interest=["apple","banana","orange","pineapple"]
#words_of_interest=["fast","quick"]
draw_features(m,num_features=20)
#draw_features(m,num_features=40)

# %%
if cooccurrence.shape[1]>8000:
    print ("No way, this matrix is too huge")
else:
    c=cooccurrence.todense()
    ut, s_ev, vt = np.linalg.svd(c.T,full_matrices=False)
    #projected=np.dot(vt.T,np.diag(s_ev))#[:,[0,1,2,3]]
    projected_densesvd=np.dot(c,ut)
    plt.plot(s_ev)
    plt.show()
    filename=dir_root.split('/')[-1]+"_dense"
    filename=os.path.join("sigmas",filename)
    print (filename)
    with open(filename, 'wb') as f:
        #pickle.dump(s_ev, f)
        #s_ev.tofile(f)
        np.savetxt(f,s_ev)
    draw_features_and_similarity(projected_densesvd,True) 
    plt.show()
   
#print(s_ev)
#projected=vt
#draw_features_and_similarity(projected,True) 
#plt.plot(s_ev)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-5616a3b121ca> in <module>()
# ----> 1 if cooccurrence.shape[1]>8000:
#       2     print ("No way, this matrix is too huge")
#       3 else:
#       4     c=cooccurrence.todense()
#       5     ut, s_ev, vt = np.linalg.svd(c.T,full_matrices=False)
#
# NameError: name 'cooccurrence' is not defined

# %% [markdown]
# #Trying scipy.sparse.linalg.svd

# %%
#cnt_singular_vectors=100
#time_start=time.time()
#m_svd = vsmlib.Model_svd_scipy(m,cnt_singular_vectors,0.5)
##result = scipy.sparse.linalg.svds(m.matrix,k=cnt_singular_vectors,return_singular_vectors=True,which='LM') # LM SM LA SA BE
#ut, s_ev, vt = result

#time_end = time.time()
#print ("took {0:0.2f} seconds".format(time_end-time_start))
#print (ut.shape)
#print (vt.shape)

# %%
#m2 = vsmlib.Model_numbered()
#m2.vocabulary = m.vocabulary
#power=0.3
#sigmas = np.power(s_ev, power)
#m2.matrix = np.dot(ut,np.diag(sigmas))
#m2.name = m.name + "_svd_{}_C{}".format(cnt_singular_vectors,power)
#m2.get_most_similar_words("fast")

#m_svd_scipy.save_to_dir("/storage/scratch/brown_svd300")
#plt.show()
#vt=np.nan_to_num(vt.T)
#draw_features_and_similarity(m_svd_scipy,True) 
m2 = vsmlib.model.Model_numbered()
#m2.load_from_dir("/mnt/work/nlp_scratch/total_w3_POS_svd400_C0.1")
m2.load_from_dir("/storage/scratch/brown_svd300/")
draw_features_and_similarity(m2) 
#plt.show
#None

# %%
plt.plot(sigmas)
#m2.get_most_similar_words("fast")

# %%
#m_svd_scipy.get_most_similar_words("fast")
row1=m2.get_row("smaller")
row2=m2.get_row("small")
row3=m2.get_row("large")
row = row1-row2+row3
m2.get_most_similar_words(row)
# Out:
# [['larger', 0.66465439303106277],
#  ['smaller', 0.60252137691726659],
#  ['largest', 0.53860906925511987],
#  ['large', 0.5332757877009896],
#  ['bigger', 0.51769768254951209],
#  ['vast', 0.51702725218728962],
#  ['huge', 0.51693829829513016],
#  ['size', 0.47562634078154331],
#  ['massive', 0.47291872995005635],
#  ['sized', 0.46423058806249107]]

# %%
m.get_row(2)
m.normalize()

# %%
wordlist = ["turkey","ankara",
            "japan","tokyo",
            "china","beijing",
            "russia","moscow",
            "france","paris",
            "germany","berlin",
            "greece","athens",
            "spain","madrid"
            ]
#wordlist = ["big","bigger","small","smaller","good","better","slow","slower"]
#wordlist = ["fast","slow","big","small","long","short","expensive","cheap"]
#mymodel = m_w2v
mymodel = m
#wordlist = ["cake","soup","sandwich","","car","bike","helicopter"]
def vis_scatter(lx,ly,wordlist):
    ax=plt.subplot()
#    ax.set_aspect('equal', 'datalim')
#    ax.set_aspect('equal')
    plt.scatter(lx,ly,c="red")
    for label, x, y in zip(wordlist, lx, ly):
        plt.annotate(
            label, 
            xy = (x, y), xytext = (-10, 10),
            textcoords = 'offset points', ha = 'right', va = 'bottom',
            bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.5),
            arrowprops = dict(arrowstyle = '-', connectionstyle = 'arc3,rad=0',color="grey"))    
    for i in range(0, len(lx), 2):
        #plt.plot(lx[i:i+2],ly[i:i+2],c="brown")   
        #plt.arrow(lx[i], ly[i], lx[i+1]-lx[i], ly[i+1]-ly[i], head_width=0.03, head_length=0.1, fc='k', ec='k')
        ax.annotate("", xy=(lx[i+1], ly[i+1]), xytext=(lx[i], ly[i]),arrowprops=dict(arrowstyle="->",color="brown"))

rows = np.empty((0,mymodel.matrix.shape[1]))
for i in wordlist:
    rows =np.vstack([rows,mymodel.get_row(i).todense()])

##p = mdp.pca(rows) 
#    #ut, s_ev, vt = np.linalg.svd(rows.T)
#ut, s_ev, vt = sklearn.decomposition.TruncatedSVD(rows)
#rows.shape

pca = sklearn.decomposition.PCA(n_components=2,whiten=True)
p = pca.fit_transform(rows)

#svd = sklearn.decomposition.TruncatedSVD(n_components=2, random_state=42)
#p = svd.fit_transform(rows)

##print(pca.explained_variance_ratio_) 
x = p[:,0]
y = p[:,1]

vis_scatter(x,y,wordlist)
plt.savefig(mymodel.name+"_capitals.pdf")

# %% [markdown]
# #Trying sparsesvd

# %%
from sparsesvd import sparsesvd
csc=m.matrix.T.tocsc()
time_start = time.time()
ut, s_ev, vt = sparsesvd(csc,cnt_singular_vectors)
projected_svdpack=np.dot(vt.T,np.diag(s_ev))
time_end = time.time()
print ("took {0:0.2f} seconds".format(time_end-time_start))
#draw_features_and_similarity(projected_svdpack,True)
# Out:
# took 19.79 seconds

# %%
plt.plot(s_ev)

# %%
#do_synonyms_test(testhelper.get_test_from_toefl("../tests/toefl/toefl"))

# %%
#do_synonyms_test(get_test_from_file("../tests/syn_easy.txt"))
from vsmlib import testhelper
testhelper.do_synonyms_test(m,testhelper.get_test_from_toefl("../tests/toefl/toefl"))
# Out:
# processing enormously
# processing provisions
# processing haphazardly
# processing prominent
# processing zenith
# processing flawed
# processing urgently
# processing consumed
# processing advent
# processing concisely
# processing salutes
# processing solitary
# processing hasten
# processing perseverance
# processing fanciful
# processing showed
# processing constantly
# processing issues
# processing furnish
# processing costly
# processing recognized
# processing spot
# processing make
# processing often
# processing easygoing
# processing debate
# processing narrow
# processing arranged
# processing infinite
# processing showy
# processing levied
# processing deftly
# processing distribute
# processing discrepancies
# processing prolific
# processing unmatched
# processing peculiarly
# processing hue
# processing hind
# processing highlight
# processing hastily
# processing temperate
# processing grin
# processing verbally
# processing physician
# processing essentially
# processing keen
# processing situated
# processing principal
# processing slowly
# processing built
# processing tasks
# processing unlikely
# processing halfheartedly
# processing annals
# processing wildly
# processing hailed
# processing command
# processing concocted
# processing prospective
# processing generally
# processing sustained
# processing perilous
# processing tranquillity
# processing dissipate
# processing primarily
# processing colloquial
# processing resolved
# processing feasible
# processing expeditiously
# processing percentage
# processing terminated
# processing uniform
# processing figure
# processing sufficient
# processing fashion
# processing marketed
# processing bigger
# processing roots
# processing normally
# '<b>enormously</b> :  appropriately(0.10) uniquely(0.22) <span style="color:green;">tremendously</span>(0.85) decidedly(0.16)<br />\n<b>provisions</b> :  <span style="color:green;">stipulations</span>(0.48) interrelations(-0.10) jurisdictions(0.34) interpretations(0.27)<br />\n<b>haphazardly</b> :  dangerously(0.25) densely(0.22) <span style="color:green;">randomly</span>(0.29) linearly(0.17)<br />\n<b>prominent</b> :  battered(0.03) ancient(0.22) mysterious(0.15) <span style="color:green;">conspicuous</span>(0.26)<br />\n<b>zenith</b> :  completion(0.06) <span style="color:green;">pinnacle</span>(0.46) outset(0.05) decline(0.11)<br />\n<b>flawed</b> :  tiny(0.03) <span style="color:green;">imperfect</span>(0.44) lustrous(-0.01) crude(0.08)<br />\n<b>urgently</b> :  typically(-0.06) conceivably(0.10) tentatively(0.17) <span style="color:green;">desperately</span>(0.48)<br />\n<b>consumed</b> :  bred(0.16) caught(0.22) <span style="color:green;">eaten</span>(0.60) supplied(0.28)<br />\n<b>advent</b> :  <span style="color:green;">coming</span>(0.20) arrest(-0.07) financing(0.11) stability(0.13)<br />\n<b>concisely</b> :  powerfully(0.25) positively(0.15) freely(0.12) <span style="color:green;">succinctly</span>(0.63)<br />\n<b>salutes</b> :  information(-0.13) ceremonies(0.24) <span style="color:green;">greetings</span>(0.24) privileges(0.04)<br />\n<b>solitary</b> :  alert(0.06) <span style="color:red;">restless</span>(0.25) <span style="text-decoration: underline; border-decoration-color: green; -moz-text-decoration-color: green;">alone</span>(0.24) fearless(0.17)<br />\n<b>hasten</b> :  permit(0.12) determine(0.12) <span style="color:green;">accelerate</span>(0.53) accompany(0.21)<br />\n<b>perseverance</b> :  <span style="text-decoration: underline; border-decoration-color: green; -moz-text-decoration-color: green;">endurance</span>(0.36) skill(0.48) <span style="color:red;">generosity</span>(0.49) disturbance(-0.08)<br />\n<b>fanciful</b> :  familiar(0.31) <span style="color:green;">imaginative</span>(0.58) apparent(-0.01) logical(0.25)<br />\n<b>showed</b> :  <span style="color:green;">demonstrated</span>(0.52) published(0.33) repeated(0.20) postponed(0.08)<br />\n<b>constantly</b> :  instantly(0.24) <span style="color:green;">continually</span>(0.84) rapidly(0.39) accidentally(0.20)<br />\n<b>issues</b> :  training(0.18) salaries(0.16) <span style="color:green;">subjects</span>(0.47) benefits(0.35)<br />\n<b>furnish</b> :  <span style="color:green;">supply</span>(0.20) impress(0.13) protect(0.11) advise(0.17)<br />\n<b>costly</b> :  <span style="color:green;">expensive</span>(0.77) beautiful(0.09) popular(0.17) complicated(0.52)<br />\n<b>recognized</b> :  successful(0.31) depicted(0.16) <span style="color:green;">acknowledged</span>(0.39) welcomed(0.29)<br />\n<b>spot</b> :  climate(0.09) latitude(0.08) sea(0.24) <span style="color:green;">location</span>(0.42)<br />\n<b>make</b> :  <span style="color:green;">earn</span>(0.42) print(0.28) trade(0.29) borrow(0.35)<br />\n<b>often</b> :  definitely(0.17) <span style="color:green;">frequently</span>(0.83) chemically(0.13) hardly(0.40)<br />\n<b>easygoing</b> :  frontier(0.03) boring(0.20) farming(0.03) <span style="color:green;">relaxed</span>(0.48)<br />\n<b>debate</b> :  war(0.38) <span style="color:green;">argument</span>(0.56) election(0.44) competition(0.31)<br />\n<b>narrow</b> :  clear(0.38) freezing(0.03) <span style="color:green;">thin</span>(0.47) poisonous(0.03)<br />\n<b>arranged</b> :  <span style="color:green;">planned</span>(0.42) explained(0.27) studied(0.17) discarded(0.17)<br />\n<b>infinite</b> :  <span style="color:green;">limitless</span>(0.50) relative(0.20) unusual(0.21) structural(0.14)<br />\n<b>showy</b> :  <span style="text-decoration: underline; border-decoration-color: green; -moz-text-decoration-color: green;">striking</span>(0.07) <span style="color:red;">prickly</span>(0.35) entertaining(0.22) incidental(0.13)<br />\n<b>levied</b> :  <span st ...

# %%
#print (get_pmi("sufficient"))
#print (get_pmi("fearing"))
#cmp_words("sufficient","fearing")

# %%
lst_sigmas=[]
legends=[]
for filename in glob.glob("./sigmas/*"):
    f=open(filename,"r")
    sigmas = np.loadtxt(f)
    lst_sigmas.append(sigmas)
    plt.plot(sigmas,label="test")
    legends.append(filename.split("/")[-1])
    f.close()
plt.legend(legends)
#print (lst_sigmas)
#plt.plot(x=range(8),y=lst_sigmas)

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %install_default_config  %install_ext  %install_profiles  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%debug  %%file  %%html  %%javascript  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
#l = [i[0] for i in testhelper.get_test_from_toefl("../tests/toefl/toefl")]
#for i in l:
    #print (i)

# %%
m_w2v = model_w2v()
m_w2v.load_from_dir("/mnt/work/nlp_scratch/_w2v/total")
wordlist = [random.choice(m_w2v.vocabulary.lst_words) for i in range(100)]
print(*wordlist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-43238e271a1b> in <module>()
# ----> 1 m_w2v = model_w2v()
#       2 m_w2v.load_from_dir("/mnt/work/nlp_scratch/_w2v/total")
#       3 wordlist = [random.choice(m_w2v.vocabulary.lst_words) for i in range(100)]
#       4 print(*wordlist)
#
# NameError: name 'model_w2v' is not defined

# %%
#m_w2v.get_most_similar_words("best")
#bstr.decode('ascii')
#draw_features_and_similarity(m_w2v,True)
m_w2v.save_to_dir("/mnt/work/nlp_scratch/w2v_np")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-724950115ec3> in <module>()
#       2 #bstr.decode('ascii')
#       3 #draw_features_and_similarity(m_w2v,True)
# ----> 4 m_w2v.save_to_dir("/mnt/work/nlp_scratch/w2v_np")
#
# NameError: name 'm_w2v' is not defined

# %%
#row1 = matr[dic_words["king"]]
#row2 = matr[dic_words["emperor"]]
#row3 = matr[dic_words["queen"]]
#wordlist = ["apple","banana","kiwi","orange","tomato","cherry","pineapple"]
wordlist = ["smaller","bigger","longer","shorter","larger"]
#wordlist = ["red","blue"]
row = np.zeros(len(m_svd_scipy.get_row(i)))
for i in wordlist:
    row += m_svd_scipy.get_row(i)
    #row = row / np.linalg.norm(row)
#plt.bar(range(0,len(row)), row, color = "green", linewidth  = 0, alpha = 1/len(wordlist))   
#plt.bar(range(0,len(row)), row, color = "green", linewidth  = 0, alpha = 0.5)   

#row = np.zeros(len(m_svd_scipy.get_row(i)))
wordlist = ["small","big","long","short","large"]
for i in wordlist:
    row -= m_svd_scipy.get_row(i)
    #row = row / np.linalg.norm(row)
#plt.bar(range(0,len(row)), row, color = "green", linewidth  = 0, alpha = 1/len(wordlist))   
plt.bar(range(0,len(row)), row, color = "red", linewidth  = 0, alpha = 0.5)   
#for i in wordlist:
#    row = m_svd_scipy.get_row(i)
#    #row = row / np.linalg.norm(row)
#    plt.bar(range(0,len(row)), row, color = "red", linewidth  = 0, alpha = 1/len(wordlist))   

#m_svd_scipy.viz_wordlist(wordlist)
plt.show()
#wordlist = ["london","paris","berlin"]
#m_svd_scipy.viz_wordlist(wordlist)
#plt.show()
er=row
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-b7269bec4a91> in <module>()
#       5 wordlist = ["smaller","bigger","longer","shorter","larger"]
#       6 #wordlist = ["red","blue"]
# ----> 7 row = np.zeros(len(m_svd_scipy.get_row(i)))
#       8 for i in wordlist:
#       9     row += m_svd_scipy.get_row(i)
#
# NameError: name 'm_svd_scipy' is not defined

# %%
#wordlist = ["apple","king","zero","france","car","circle","run","hot","myself"]
#viz_wordlist(wordlist2)
#wordlist = [i*2 for i in range(10)]
wordlist = [random.choice(m_svd_scipy.vocabulary.lst_words) for i in range(20)]
print(wordlist)
#m_w2v.viz_wordlist(wordlist)
m_svd_scipy.viz_wordlist(wordlist)

plt.show()
# Out:
# ['pinching', 'tiananmen', 'bignall', 'saracen', 'ibu', 'engelbart', 'wendell', 'littledale', 'erikson', 'warped', 'sarcophagi', 'aonb', 'lowest', 'newark', 'midhat', 'greyish', 'buzzers', 'outrunning', 'nosema', 'arguedas']

# %%
#vec= m_svd_scipy.get_row("small")
#vec[-1]=-vec[-1]
#vec=vec+er
#m_svd_scipy.get_most_similar_words(vec)
#m_svd_scipy.get_most_similar_words("fast")
row1=m_svd_scipy.get_row("smaller")
row2=m_svd_scipy.get_row("small")
row3=m_svd_scipy.get_row("far")
row = row1-row2+row3
m_svd_scipy.get_most_similar_words(row)
# Out:
# [['far', 0.66592201514235005],
#  ['certainly', 0.44445207323601488],
#  ['much', 0.44432489777265527],
#  ['longer', 0.42619353107118185],
#  ['ever', 0.4183633304391724],
#  ['considerably', 0.41493452321963353],
#  ['least', 0.41451602943566634],
#  ['none', 0.40404042353959957],
#  ['generally', 0.4027013469763554],
#  ['anything', 0.40260018816305665]]

# %%
import gzip
class Model_glove(vsmlib.Model_numbered):
    def __init__(self):
        self.name="glove"
    def load_from_file(self,path):
        i=0;
        matr = None
        self.vocabulary = vsmlib.Vocabulary()
        rows=[]
        with gzip.open(path) as f:
            for line in f:
                tokens  = line.split()
                word = tokens[0].decode()
                m.vocabulary.dic_words_ids[word]=i;
                m.vocabulary.lst_words.append(word)
                str_vec=tokens[1:]
                #print (str_vec)
                row = np.zeros(len(str_vec),dtype=np.float32)
                for j in range(len(str_vec)) :
                    row[j]=float(str_vec[j])
                rows.append(row)
                i+=1
        self.matrix=np.zeros((len(rows),len(rows[0])),dtype=np.float32)
        self.name+="_{}".format(len(rows[0]))
        for i in (range(len(rows))):
            self.matrix[i]=rows[i]

# %%
path ="/mnt/work/nlp_scratch/glove/glove.6B.300d.txt.gz"
m=Model_glove()
m.load_from_file(path)
words_of_interest=["apple","banana","orange","pineapple"]
draw_features(m)
#m.matrix
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-50-da5bc801ef00> in <module>()
#       1 path ="/mnt/work/nlp_scratch/glove/glove.6B.300d.txt.gz"
#       2 m=Model_glove()
# ----> 3 m.load_from_file(path)
#       4 words_of_interest=["apple","banana","orange","pineapple"]
#       5 draw_features(m)
#
# <ipython-input-49-aa51a8c8289c> in load_from_file(self, path)
#       8         self.vocabulary = vsmlib.Vocabulary()
#       9         rows=[]
# ---> 10         with gzip.open(path) as f:
#      11             for line in f:
#      12                 tokens  = line.split()
#
# /usr/lib/python3.4/gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      50     gz_mode = mode.replace("t", "")
#      51     if isinstance(filename, (str, bytes)):
# ---> 52         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      53     elif hasattr(filename, "read") or hasattr(filename, "write"):
#      54         binary_file = GzipFile(None, gz_mode, compresslevel, filename)
#
# /usr/lib/python3.4/gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     179             mode += 'b'
#     180         if fileobj is None:
# --> 181             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     182         if filename is None:
#     183             filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/work/nlp_scratch/glove/glove.6B.300d.txt.gz'

# %%
#m.save_to_dir("/mnt/work/nlp_scratch/test/glove_300")
m.normalize()

# %%
aa=m.matrix
a=aa[:1200].T
#my_cm = mpl.cm.get_cmap('RdBu')
my_cm = mpl.cm.get_cmap('RdBu')
normed_data = (a - np.min(a)) / (np.max(a) - np.min(a))
mapped_datau8 = (255 * my_cm(normed_data)).astype('uint8')
im = PIL.Image.fromarray(np.uint8(mapped_datau8))
im
# Out:
# <PIL.Image.Image image mode=RGBA size=1200x300 at 0x7F2C912C6C88>

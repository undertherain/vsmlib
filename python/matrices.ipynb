# %%
import os
import sys
import math
import glob
import imp
import importlib
import socket
import time
import random
import numpy as np
import scipy
from scipy import sparse
from scipy.spatial.distance import cosine
import sklearn
import sklearn.decomposition
import matplotlib as mpl
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import HTML
from myutils.formathelper import sizeof_fmt,countof_fmt
from IPython.core import display
from PIL import Image
from io import BytesIO
import vsmlib
from vsmlib.visualize import draw_features,draw_features_and_similarity,plotvectors,wordlist_to_rows,rows_to_img_array
# %matplotlib inline
mpl.rcParams['figure.figsize'] = (24.0, 8.0)
import brewer2mpl
import pandas
from pandas.tools.plotting import parallel_coordinates

# %%
def display_pil_image(im):
   """Displayhook function for PIL Images, rendered as PNG."""
   b = BytesIO()
   im.save(b, format='png')
   data = b.getvalue()
   ip_img = display.Image(data=data, format='png', embed=True)
   return ip_img._repr_png_()

png_formatter = get_ipython().display_formatter.formatters['image/png']
dpi = png_formatter.for_type(Image.Image, display_pil_image)

# %%
if socket.gethostname()=="cypress":
    dir_root="/storage/scratch/SVD/explicit_Giga_2w_svd_500_C0.6/"    
if socket.gethostname()=="ashtree":  
    dir_root="/mnt/work/nlp_scratch/SVD/explicit_Giga_3w_pos_svd_500_C0.6/"
    #dir_root="/mnt/work/nlp_scratch/test"
if socket.gethostname()=="rc017.m.gsic.titech.ac.jp":
    dir_root="/home/blackbird/data/scratch/brown"

# %%
#m=load_from_dir("/storage/scratch/brown_svd300")
#imp.reload(vsmlib.model)

#models=[]
m=vsmlib.model.load_from_dir(dir_root)
#m=vsmlib.model.load_from_dir("/mnt/work/nlp_scratch/glove/glove.840B.300d")
#m=vsmlib.model.load_from_dir("/mnt/work/nlp_scratch/glove/glove.6b.wiki_giga")

#m=vsmlib.model.load_from_dir("/storage/scratch/_w2v")
#m=vsmlib.model.load_from_dir("/storage/scratch/SVD/explicit_BNC_w3_pos_svd_400_C0.1")

#print(m.vocabulary.get_id("apple"))
#m.vocabulary.get_word_by_id(3241)
# Out:
# this is dense

# %%
#m.clip_negatives()
#m = svd;
#m.normalize()
print(m.name)
print(m.provenance)
print(m.vocabulary.get_id("бежать"))
print(m.vocabulary.get_word_by_id(2112))
#m.vocabulary.lst_words
# Out:
# explicit_Giga_3w_pos_svd_500_C0.6
#
# 2112
# бежать

# %%
#words_of_interest=["germany","berlin","japan","tokyo"]
#words_of_interest=["fast","quick","rapid", "swift", "slow","sluggish", "delayed","apple"]
#words_of_interest=["apple","banana","pear"]
#words_of_interest=["quick","fast"]
words_of_interest=["яблоко","груша"]
#draw_features_and_similarity(m,words_of_interest)
draw_features(m,words_of_interest,num_features=40)
#plotvectors(m)
#print(1)
#m.viz_wordlist(words_of_interest,colored=True,show_legend=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-124-9151150b9ae0> in <module>()
#       5 words_of_interest=["яблоко","груша"]
#       6 #draw_features_and_similarity(m,words_of_interest)
# ----> 7 draw_features(m,words_of_interest,num_features=40)
#       8 #plotvectors(m)
#       9 #print(1)
#
# /home/blackbird/Cloud/Dropbox/Projects/NLP/DistibutionalSimilarity/python/vsmlib/visualize.py in draw_features(mm, words_of_interest, num_features)
#      57     rows,cols,xlabels=mm.filter_submatrix(words_of_interest,num_features)
#      58     ax=plt.subplot()
# ---> 59     plot_heat(ax,cols,xlabels,words_of_interest)
#      60
#      61 def plotvectors(m):
#
# /home/blackbird/Cloud/Dropbox/Projects/NLP/DistibutionalSimilarity/python/vsmlib/visualize.py in plot_heat(ax, m, xlabels, ylabels)
# ...

# %%
m.get_most_similar_words("яблоко")
# Out:
# [['яблоко', 1.0000002509070518],
#  ['банан', 0.85060039862955639],
#  ['ананас', 0.80463221298284804],
#  ['апельсин', 0.77823260538540651],
#  ['арбуз', 0.76233159777419435],
#  ['груша', 0.7570662676513531],
#  ['абрикос', 0.7557149762504235],
#  ['тыква', 0.74587994525895351],
#  ['чернослив', 0.74359160071291008],
#  ['орех', 0.74340236929550996]]

# %%
v1=m.get_row("fast")
lst_results=[]
for w in m.vocabulary.lst_words:
    v2=m.get_row(w)
    distance=scipy.spatial.distance.euclidean(v1,v2)
    lst_results.append((w,distance))
    lst_results=sorted(lst_results,key=lambda x: x[1])
    lst_results=lst_results[:10]
lst_results
# Out:
# [('fast', 0.0),
#  ('different', 1.6206650733947754),
#  ('soldier', 1.6573255062103271),
#  ('plug', 1.661441445350647),
#  ('ukrainian', 1.6815400123596191),
#  ('applied', 1.6905206441879272),
#  ('making', 1.6905286312103271),
#  ('sociology', 1.6991404294967651),
#  ('cognitive', 1.7006421089172363),
#  ('intellectual', 1.7056341171264648)]

# %%
fig,ax= plt.subplots()
colors = brewer2mpl.get_map('Set2', 'qualitative', 8).mpl_colors
i=0
for w in words_of_interest:
    row = m.get_row(w)
    #plt.scatter(range(0,len(row)), row, label=w, color=colors[i], alpha=0.5, marker='o' )
    plt.bar(range(0,len(row)), row, color = colors[i], linewidth  = 0, alpha = 0.6,  label=w)   
    i+=1
ax.set_xlim(0,400)
plt.legend()

# %%
#create mask
row1=m.get_row("pear")
row2=m.get_row()

# %%
words_of_interest=[i[0] for i in lst_results]
rows=vsmlib.visualize.wordlist_to_rows(m,words_of_interest)
row_std = np.std(rows, axis=0, dtype=None, out=None, keepdims=False)
plt.bar(range(0,len(row_std)), row_std[row_std.argsort()], linewidth  = 0, color="b", alpha = 0.5,  label="close to fast")   
words_of_interest=["run","zero","banana","london","red","cold","human","tea"]
rows=vsmlib.visualize.wordlist_to_rows(m,words_of_interest)
row_std = np.std(rows, axis=0, dtype=None, out=None, keepdims=False)
plt.bar(range(0,len(row_std)), row_std[row_std.argsort()], linewidth  = 0, color="r", alpha = 0.5,  label="random")   
plt.legend()

# %%
#m.get_most_similar_words("fast")
#m.viz_wordlist(words_of_interest,colored=True,show_legend=True)
cnt=0;
fig,ax= plt.subplots()
for i in words_of_interest:
    row = m.get_row(i)
    #plt.bar(range(0,len(row)), row, color = colors[cnt], linewidth  = 0, alpha = 0.6,  label=i)   
    #plt.plot(range(0,len(row)), row, label=i, marker='o' )
    plt.scatter(range(0,len(row)), row, label=i, color="k", alpha=0.5, marker='o' )
    #plt.boxplot(row)
#    plt.scatter(range(0,len(row)), row, label=i, color = colors[cnt], marker='o' )
    cnt+=1;
    #plt.legend()
ax.set_xlim(0,400)
# Out:
# (0, 400)

# %% [markdown]
# #Trying scipy.sparse.linalg.svd

# %%
#cnt_singular_vectors=100
#time_start=time.time()
#m_svd = vsmlib.Model_svd_scipy(m,cnt_singular_vectors,0.5)
##result = scipy.sparse.linalg.svds(m.matrix,k=cnt_singular_vectors,return_singular_vectors=True,which='LM') # LM SM LA SA BE
#ut, s_ev, vt = result

#time_end = time.time()
#print ("took {0:0.2f} seconds".format(time_end-time_start))
#print (ut.shape)
#print (vt.shape)

# %%
#m2 = vsmlib.Model_numbered()
#m2.vocabulary = m.vocabulary
#power=0.3
#sigmas = np.power(s_ev, power)
#m2.matrix = np.dot(ut,np.diag(sigmas))
#m2.name = m.name + "_svd_{}_C{}".format(cnt_singular_vectors,power)
#m2.get_most_similar_words("fast")

#m_svd_scipy.save_to_dir("/storage/scratch/brown_svd300")
#plt.show()
#vt=np.nan_to_num(vt.T)
#draw_features_and_similarity(m_svd_scipy,True) 
m2 = vsmlib.model.Model_numbered()
#m2.load_from_dir("/mnt/work/nlp_scratch/total_w3_POS_svd400_C0.1")
m2.load_from_dir("/storage/scratch/brown_svd300/")
draw_features_and_similarity(m2) 
#plt.show
#None

# %%
plt.plot(sigmas)
#m2.get_most_similar_words("fast")

# %%
#m_svd_scipy.get_most_similar_words("fast")
row1=m2.get_row("smaller")
row2=m2.get_row("small")
row3=m2.get_row("large")
row = row1-row2+row3
m2.get_most_similar_words(row)
# Out:
# [['larger', 0.66465439303106277],
#  ['smaller', 0.60252137691726659],
#  ['largest', 0.53860906925511987],
#  ['large', 0.5332757877009896],
#  ['bigger', 0.51769768254951209],
#  ['vast', 0.51702725218728962],
#  ['huge', 0.51693829829513016],
#  ['size', 0.47562634078154331],
#  ['massive', 0.47291872995005635],
#  ['sized', 0.46423058806249107]]

# %%
m.normalize()

# %%
#m.get_row(2)
def wordlist_from_pairs(name):
    with open(name) as f:
        pairs = [y for y in [x.split() for x in f.readlines() if len(x)>3]]
        wordlist = [item for sublist in pairs for item in sublist]
    return wordlist
mymodel = m
wordlist = wordlist_from_pairs("../data/pairs/verbs.txt")

# %%
#wordlist=wordlist[:40]
#wordlist = ["big","bigger","small","smaller","good","better","slow","slower","short","shorter"]
#wordlist = ["fast","slow","big","small","long","short","expensive","cheap","good","bad"]
mpl.rcParams['figure.figsize'] = (20.0, 10.0)
def vis_scatter(lx,ly,wordlist):
    ax=plt.subplot()
#    ax.set_aspect('equal', 'datalim')
#    ax.set_aspect('equal')
    plt.scatter(lx,ly,c="red")
    for label, x, y in zip(wordlist, lx, ly):
        plt.annotate(
            label, 
            xy = (x, y), xytext = (-10, 10),
            textcoords = 'offset points', ha = 'right', va = 'bottom',
            bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.5),
            arrowprops = dict(arrowstyle = '-', connectionstyle = 'arc3,rad=0',color="grey"))    
    for i in range(0, len(lx), 2):
        #plt.plot(lx[i:i+2],ly[i:i+2],c="brown")   
        #plt.arrow(lx[i], ly[i], lx[i+1]-lx[i], ly[i+1]-ly[i], head_width=0.03, head_length=0.1, fc='k', ec='k')
        ax.annotate("", xy=(lx[i+1], ly[i+1]), xytext=(lx[i], ly[i]),arrowprops=dict(arrowstyle="->",color="brown"))

rows = np.empty((0,mymodel.matrix.shape[1]))
for i in wordlist:
#    rows =np.vstack([rows,mymodel.get_row(i).todense()])
    rows =np.vstack([rows,mymodel.get_row(i)])

##p = mdp.pca(rows) 
#ut, s_ev, vt = np.linalg.svd(rows.T)
#ut, s_ev, vt = sklearn.decomposition.TruncatedSVD(rows)
#rows.shape

pca = sklearn.decomposition.PCA(n_components=6,whiten=True)
p = pca.fit_transform(rows)

#svd = sklearn.decomposition.TruncatedSVD(n_components=2, random_state=1)
#p = svd.fit_transform(rows)

##print(pca.explained_variance_ratio_) 

x = p[:,2]
y = p[:,4]

vis_scatter(x,y,wordlist)
plt.savefig(mymodel.name+"_imperfect.pdf", bbox_inches='tight')

# %%
import inspect
text_color="#cccccc"
def set_ax_params(ax):
    ax.spines['bottom'].set_color(text_color)
    ax.spines['top'].set_color(text_color)
    ax.spines['left'].set_color(text_color)
    ax.spines['right'].set_color(text_color)
    ax.tick_params(colors=text_color)

# %%
ax = plt.subplot('111')
set_ax_params(ax)

rows = np.empty((0,mymodel.matrix.shape[1]))
for i in wordlist:
#    rows =np.vstack([rows,mymodel.get_row(i).todense()])
    rows =np.vstack([rows,mymodel.get_row(i)])
pca = sklearn.decomposition.PCA(n_components=7,whiten=True)
p = pca.fit_transform(rows)
df = pandas.DataFrame(p, index=["transitive","intransitive"]*int(p.shape[0]/2))
df.reset_index(level=0, inplace=True)
parallel_coordinates(df,"index",alpha=0.6)
#plt.grid(b=True, which='major', color='r', linestyle='-')
#plt.grid(b=True, which='minor', color='r', linestyle='--')
plt.savefig("parallel_alpha_"+mymodel.name+"_verbs.pdf", bbox_inches='tight',transparent=True)

# %% [markdown]
# #Trying sparsesvd

# %%
from sparsesvd import sparsesvd
csc=m.matrix.T.tocsc()
time_start = time.time()
ut, s_ev, vt = sparsesvd(csc,cnt_singular_vectors)
projected_svdpack=np.dot(vt.T,np.diag(s_ev))
time_end = time.time()
print ("took {0:0.2f} seconds".format(time_end-time_start))
#draw_features_and_similarity(projected_svdpack,True)
# Out:
# took 19.79 seconds

# %%
plt.plot(s_ev)

# %%
#do_synonyms_test(testhelper.get_test_from_toefl("../tests/toefl/toefl"))

# %%
#do_synonyms_test(get_test_from_file("../tests/syn_easy.txt"))
#from vsmlib import testhelper
#testhelper.do_synonyms_test(m,testhelper.get_test_from_toefl("../tests/toefl/toefl"))

# %%
#print (get_pmi("sufficient"))
#print (get_pmi("fearing"))
#cmp_words("sufficient","fearing")

# %%
lst_sigmas=[]
legends=[]
for filename in glob.glob("./sigmas/*"):
    f=open(filename,"r")
    sigmas = np.loadtxt(f)
    lst_sigmas.append(sigmas)
    plt.plot(sigmas,label="test")
    legends.append(filename.split("/")[-1])
    f.close()
plt.legend(legends)
#print (lst_sigmas)
#plt.plot(x=range(8),y=lst_sigmas)

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %install_default_config  %install_ext  %install_profiles  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
#l = [i[0] for i in testhelper.get_test_from_toefl("../tests/toefl/toefl")]
#for i in l:
    #print (i)

# %%
m_w2v = model_w2v()
m_w2v.load_from_dir("/mnt/work/nlp_scratch/_w2v/total")
wordlist = [random.choice(m_w2v.vocabulary.lst_words) for i in range(100)]
print(*wordlist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-43238e271a1b> in <module>()
# ----> 1 m_w2v = model_w2v()
#       2 m_w2v.load_from_dir("/mnt/work/nlp_scratch/_w2v/total")
#       3 wordlist = [random.choice(m_w2v.vocabulary.lst_words) for i in range(100)]
#       4 print(*wordlist)
#
# NameError: name 'model_w2v' is not defined

# %%
#m_w2v.get_most_similar_words("best")
#bstr.decode('ascii')
#draw_features_and_similarity(m_w2v,True)
#m_w2v.save_to_dir("/mnt/work/nlp_scratch/w2v_np")
m.normalize()

# %%
wordlist = [s.strip() for s in open("../data/animals.txt").readlines()]
print(wordlist)
#wordlist = ["apple","banana","cat","rabbit","cow","lion","elephant","donkey","goat","kangaroo","sheep","wolf","fox"]
#wordlist = ["dog","dog"]
#wordlist = ["run","swim","drive","go","thow","send","say","listed","see","watch","play","sing","stay"]
#row1 = matr[dic_words["king"]]
#row2 = matr[dic_words["emperor"]]
#row3 = matr[dic_words["queen"]]
#wordlist = ["apple","banana","kiwi","orange","tomato","cherry","pineapple"]
#wordlist = ["smaller","bigger","longer","shorter","larger"]
#wordlist = ["red","blue"]
#rows = np.zeros(len(m.get_row(wordlist[0])))
rows = m.get_row(wordlist[0])
for i in wordlist[1:]:
    #row += m.get_row(i)
    rows =np.vstack([rows,m.get_row(i)])
    #row = row / np.linalg.norm(row)
row_mean = np.mean(rows, axis=0, dtype=None, out=None, keepdims=False)
row_std=np.ones(len(row_mean))
row_std = np.std(rows, axis=0, dtype=None, out=None, keepdims=False)
plt.bar(range(0,len(row_mean)), row_std, color = "grey", linewidth  = 0, alpha = 0.4,label="std")   
target = m.get_row("dig")
print ("sim target to avg = ",1-scipy.spatial.distance.cosine(target,row_mean))
rows.shape
#plt.show()
mask=[row_std>1]
row_std[mask]=0
mask= np.logical_not(mask)[0]
row_std[mask]=1
#[not x for x in mask]

target=target*row_std
row_mean=row_mean*row_std
plt.bar(range(0,len(row_mean)), row_mean, color = "green", linewidth  = 0, alpha = 0.5 , label="mean")   
plt.bar(range(0,len(target)), target, color = "red", linewidth  = 0, alpha = 0.5, label="target")   
plt.legend()
#plt.show()
print ("sim target to masked avg =", 1-scipy.spatial.distance.cosine(target,row_mean))
# Out:
# ['bear', 'cat', 'cow', 'coyote', 'deer', 'dog', 'donkey', 'duck', 'elephant', 'fox', 'goat', 'gorilla', 'horse', 'kangaroo', 'lion', 'leopard', 'monkey', 'rabbit', 'sheep', 'wolf']
# sim target to avg =
#  0.0464307238743
# sim target to masked avg =
#  0.0464307238743

# %%
#wordlist = ["apple","king","zero","france","car","circle","run","hot","myself"]
#wordlist = ["fast","quick"]
#viz_wordlist(wordlist2)
#wordlist = [i*2 for i in range(10)]
m.viz_wordlist(wordlist)
#plt.savefig(m.name+"_animals.pdf")
#plt.show()
#wordlist = [random.choice(m.vocabulary.lst_words) for i in range(len(wordlist))]
#print(wordlist[:30])
#m.viz_wordlist(wordlist)
#plt.savefig(m.name+"_random.pdf")
#plt.show()

# %%
#vec= m_svd_scipy.get_row("small")
#vec[-1]=-vec[-1]
#vec=vec+er
#m_svd_scipy.get_most_similar_words(vec)
#m_svd_scipy.get_most_similar_words("fast")
row1=m.get_row("smaller")
row2=m.get_row("small")
row3=m.get_row("far")
row = row1-row2+row3
m.get_most_similar_words(row)
# Out:
# [['far', 0.78948663201828895],
#  ['than', 0.65419150870156184],
#  ['smaller', 0.62076478093864895],
#  ['considerably', 0.59895784159794085],
#  ['bigger', 0.59708557335880141],
#  ['much', 0.59679622064366555],
#  ['less', 0.58209659927765833],
#  ['larger', 0.57741673680821592],
#  ['more', 0.56714982505154687],
#  ['significantly', 0.56484752230696844]]

# %%
path ="/mnt/work/nlp_scratch/glove/glove.6B.300d.txt.gz"
words_of_interest=["apple","banana","orange","pineapple"]
#m.matrix
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-da5bc801ef00> in <module>()
#       3 m.load_from_file(path)
#       4 words_of_interest=["apple","banana","orange","pineapple"]
# ----> 5 draw_features(m)
#       6 #m.matrix
#
# TypeError: draw_features() missing 1 required positional argument: 'words_of_interest'

# %%
draw_features(m,words_of_interest)

# %%
#m.save_to_dir("/mnt/work/nlp_scratch/test/glove_300")
m.normalize()

# %%
from nltk.corpus import wordnet as wn

# %%
#wn.synsets('dog') 
#animals = wn.synset('animal.n.01')
animals = wn.synset('placental.n.01')

animals.hyponyms()
# Out:
# [Synset('aardvark.n.01'),
#  Synset('aquatic_mammal.n.01'),
#  Synset('bat.n.01'),
#  Synset('buck.n.05'),
#  Synset('bull.n.11'),
#  Synset('carnivore.n.01'),
#  Synset('cow.n.02'),
#  Synset('digitigrade_mammal.n.01'),
#  Synset('doe.n.02'),
#  Synset('edentate.n.01'),
#  Synset('fissipedia.n.01'),
#  Synset('flying_lemur.n.01'),
#  Synset('hyrax.n.01'),
#  Synset('insectivore.n.01'),
#  Synset('lagomorph.n.01'),
#  Synset('livestock.n.01'),
#  Synset('pachyderm.n.01'),
#  Synset('pangolin.n.01'),
#  Synset('plantigrade_mammal.n.01'),
#  Synset('primate.n.02'),
#  Synset('proboscidean.n.01'),
#  Synset('rodent.n.01'),
#  Synset('tree_shrew.n.01'),
#  Synset('unguiculata.n.01'),
#  Synset('unguiculate.n.01'),
#  Synset('ungulata.n.01'),
#  Synset('ungulate.n.01'),
#  Synset('yearling.n.03')]

# %%
import sys
sys.version_info
# Out:
# sys.version_info(major=3, minor=4, micro=3, releaselevel='final', serial=0)

# %%
#a=np.zeros(shape=(2,20),dtype=float,order="F")
#a[0,1]=-0.5
#a[1,0]=0.5
#a
m.normalize()
words2=["run","walk","swim","dare"]
a=wordlist_to_rows(m,words2)

# %%
#create image of a proper size
rows_to_img_array(a)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x300 at 0x7F9ED5F4C668>

# %%
row_std = np.std(a, axis=0, dtype=None, out=None, keepdims=False)
row_std.shape=(1,400)
#im = rows_to_img_array(row_std)

#(row_std)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-51ed4fea71f4> in <module>()
# ----> 1 row_std = np.std(a, axis=0, dtype=None, out=None, keepdims=False)
#       2 row_std.shape=(1,400)
#       3 #im = rows_to_img_array(row_std)
#       4
#       5 #(row_std)
#
# NameError: name 'np' is not defined

# %%
a = np.zeros((4,4))
a[1,1]=1
a[1,2]=1
a[2,1]=1
a[2,2]=1
a[3,3]=0.5

# %%
my_cm = mpl.cm.get_cmap('Blues')
my_cm(a)
# Out:
# array([[[ 0.96862745,  0.98431373,  1.        ,  1.        ],
#         [ 0.96862745,  0.98431373,  1.        ,  1.        ],
#         [ 0.96862745,  0.98431373,  1.        ,  1.        ],
#         [ 0.96862745,  0.98431373,  1.        ,  1.        ]],
#
#        [[ 0.96862745,  0.98431373,  1.        ,  1.        ],
#         [ 0.03137255,  0.1882353 ,  0.41960785,  1.        ],
#         [ 0.03137255,  0.1882353 ,  0.41960785,  1.        ],
#         [ 0.96862745,  0.98431373,  1.        ,  1.        ]],
#
#        [[ 0.96862745,  0.98431373,  1.        ,  1.        ],
#         [ 0.03137255,  0.1882353 ,  0.41960785,  1.        ],
#         [ 0.03137255,  0.1882353 ,  0.41960785,  1.        ],
#         [ 0.96862745,  0.98431373,  1.        ,  1.        ]],
#
#        [[ 0.96862745,  0.98431373,  1.        ,  1.        ],
#         [ 0.96862745,  0.98431373,  1.        ,  1.        ],
#         [ 0.96862745,  0.98431373,  1.        ,  1.        ],
# ...

# %%
mapped_datau8 = (255 * my_cm(a)).astype('uint8')
im = Image.fromarray(np.uint8(mapped_datau8))
im.save("temp.png")

# %%
import os
import socket
import time
import numpy as np
import scipy
import random
from scipy import sparse
import sklearn
from sklearn.metrics import pairwise_distances
from scipy.spatial.distance import cosine
from IPython.display import HTML
import matplotlib as mpl
from matplotlib import pyplot as plt
import math
import glob
import imp
import vsmlib
from vsmlib import testhelper,matrix,similarity
#from vsmlib.vocabulary import get_id,get_word_by_id
from myutils.formathelper import sizeof_fmt,countof_fmt
#from vsmlib.similarity import cmp_words
# %matplotlib inline

# %%
#imp.reload(vsmlib.matrix)
imp.reload(vsmlib.similarity)

if socket.gethostname()=="cypress":  dir_root="/storage/scratch/BNC"
if socket.gethostname()=="ashtree":  dir_root="/mnt/work/nlp_scratch/BNC"
if socket.gethostname()=="rc017.m.gsic.titech.ac.jp":  dir_root="/home/blackbird/data/scratch/brown"
max_width=25

# %%
class Vocabulary(object):
    def get_id(self,w):
        try:
            return self.dic_words_ids[w]
        except KeyError:
            return -1
    def get_word_by_id(self,i):
        return(self.lst_words[i])

# %%
class Vocabulary_cooccurrence(Vocabulary):
    def get_frequency(i):
        if i<0: return 0
        return(l_frequencies[i])
    def load_dic_from_file(self,filename):
        rdic={}
        f=open(os.path.join(self.dir_root,filename), encoding='utf-8', errors='replace')
        lines=f.readlines()
        for line in lines:
            tokens=line.split()
            rdic[tokens[0]]=np.int64(tokens[-1])
        f.close()
        return rdic
    def load(self,path,verbose=False):
        t_start=time.time()
        #global dir_root,dic_words_ids,l_frequencies,lst_words
        self.dir_root=path
        self.dic_words_ids = self.load_dic_from_file("ids")
        l_frequencies = np.fromfile(open(os.path.join(dir_root,"freq_per_id")),dtype=np.uint64)
        self.lst_words=[]
        self.lst_words=self.lst_words+([i[0] for i in sorted(self.dic_words_ids.items(), key=lambda x: x[1])])
        t_end=time.time()
        assert len(self.lst_words)==len(self.dic_words_ids)
        if verbose:
            cnt_words=len(lst_words)
            print ("Vocabulary loaded in {0:0.2f} seconds".format(t_end-t_start))
            print ("{} words ({}) in vocabulary".format(cnt_words,countof_fmt(cnt_words)))

class model(object):
    def get_x_label(self,i):
        return self.vocabulary.get_word_by_id(i)
    
    def get_most_informative_columns(self,rows):
        xdim=rows.shape[1]
        scores=np.zeros(xdim)
        for i in range(rows.shape[0]):
            row = rows[i]/np.linalg.norm(rows[i])
            for j in range(len(row)):
                scores[j]+=row[j]
        tops = np.argsort(scores)
        return list(reversed(tops[-max_width:]))        
    def filter_rows(self,ids_of_interest):
        #return (cooccurrence[1].todense()[:width])
        xdim=self.matrix.shape[1]
        dense=np.empty([0,xdim])
        #dense=np.empty([0,width])
        for i in ids_of_interest:
            if i<0: continue
            if scipy.sparse.issparse(self.matrix):
                row=self.matrix[i].todense()
            else:
                row=self.matrix[i]
            row = np.asarray(row)
            row = np.reshape(row,(xdim))
            #dense=np.vstack([dense,row[:width]])
            dense=np.vstack([dense,row])
        return (dense)
    def filter_submatrix(self,lst_words_initial):
        words_of_interest=[w for w in lst_words_initial if self.vocabulary.get_id(w)>=0]
        ids_of_interest=[self.vocabulary.get_id(w) for w in words_of_interest]
        rows = self.filter_rows(ids_of_interest)
        xdim=rows.shape[1]
        max_width = 25
        width=min(xdim,max_width)
        vert = None # np.empty((rows.shape[0],0))
        cols = self.get_most_informative_columns(rows)
        #print (cols)
        for i in cols:
            if vert is None:
                vert = (rows[:,i])
            else:
                vert=np.vstack([vert,rows[:,i]])
        labels=[self.get_x_label(i) for i in cols]
        return rows,vert.T,labels    
    def cmp_vectors(self,r1,r2):
        if sparse.issparse(r1):
            c= r1.dot(r2.T)/(np.linalg.norm(r1.data)*np.linalg.norm(r2.data))
            c= c[0,0]
            if math.isnan(c): return 0
            return c
        else:
            c= scipy.spatial.distance.cosine(r1,r2)
            if math.isnan(c): return 0
            return 1-c    
    def get_most_similar_vectors(self,u):
        scores=[]
        for i in range(self.matrix.shape[0]):
            scores.append([self.cmp_vectors(u,self.matrix[i]),i])
        scores.sort()
        result=[]
        for q in reversed(scores[-10:]):
            if q[0]>0:
                result.append([q[1],q[0]])
        return result
    def get_most_similar_words(self,w):
        if isinstance(w, str):
            vec= self.matrix[self.vocabulary.get_id(w)]
        else:
            vec=w
        rows = self.get_most_similar_vectors(vec)
        results=[]
        for i in rows:
            results.append([self.vocabulary.get_word_by_id(i[0]),i[1]])
        return results
    def get_row(self,w):
        i = self.vocabulary.get_id(w)
        if i<0: return None
        row = self.matrix[i]
        return row
    
class model_explicit(model):
    def __init__(self):
        provenance=""
        pass
    def load(self,path):
        self.vocabulary = Vocabulary_cooccurrence()
        self.vocabulary.load(path)
        self.matrix = matrix.load_matrix_csr(dir_root,zero_negatives=False,verbose=True)
    
m = model_explicit()
m.load(dir_root)
#m.filter_submatrix(["fast","quick"])
#v.load(dir_root)
#v.get_word_id("fast")
#v.get_word_by_id(50379)
#dic_words_ids={}
#dic_words_ids["a"]
# Out:
# Matrix loaded in 0.10 sec
# Matrix dimentions : (190296, 190296) (190.3K unique words in the corpus )
# Would take 2.1TiB if stored in dense format
# Cnt nonzero elements = 17991034 (should take about 1.1GiB of memory space
# Sparsity = 0.0497%

# %%
m.get_most_similar_words("best")
#vocabulary.report_rare()
#vocabulary.l_frequencies
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-7163aafc7eb0> in <module>()
# ----> 1 m.get_most_similar_words("best")
#       2 #vocabulary.report_rare()
#       3 #vocabulary.l_frequencies
#
# <ipython-input-49-cb028db6911d> in get_most_similar_words(self, w)
#      98         else:
#      99             vec=w
# --> 100         rows = self.get_most_similar_vectors(vec)
#     101         results=[]
#     102         for i in rows:
#
# <ipython-input-49-cb028db6911d> in get_most_similar_vectors(self, u)
#      86         scores=[]
#      87         for i in range(self.matrix.shape[0]):
# ---> 88             scores.append([self.cmp_vectors(u,self.matrix[i]),i])
#      89         scores.sort()
#      90         result=[]
#
# <ipython-input-49-cb028db6911d> in cmp_vectors(self, r1, r2)
#      75     def cmp_vectors(self,r1,r2):
#      76         if sparse.issparse(r1):
# ---> 77             c= r1.dot(r2.T)/(np.linalg.norm(r1.data)*np.linalg.norm(r2.data))
#      78             c= c[0,0]
#      79             if math.isnan(c): return 0
#
# /usr/local/lib/python3.4/dist-packages/scipy/sparse/base.py in dot(self, other)
#     244
#     245         """
# --> 246         return self * other
#     247
#     248     def __eq__(self, other):
#
# /usr/local/lib/python3.4/dist-packages/scipy/sparse/base.py in __mul__(self, other)
#     307             if self.shape[1] != other.shape[0]:
#     308                 raise ValueError('dimension mismatch')
# --> 309             return self._mul_sparse_matrix(other)
#     310
#     311         try:
#
# /usr/local/lib/python3.4/dist-packages/scipy/sparse/compressed.py in _mul_sparse_matrix(self, other)
#     505            np.asarray(other.indices, dtype=idx_dtype),
#     506            other.data,
# --> 507            indptr, indices, data)
#     508
#     509         return self.__class__((data,indices,indptr),shape=(M,N))
#
# KeyboardInterrupt:

# %%
import pylab
pylab.rcParams['figure.figsize'] = (18.0, 8.0)
from matplotlib.colors import Normalize

class MidpointNormalize(Normalize):
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        # I'm ignoring masked values and all kinds of edge cases to make a
        # simple example...
        x, y = [self.vmin, self.midpoint, self.vmax], [0, 0.5, 1]
        return np.ma.masked_array(np.interp(value, x, y))

def plot_heat(ax,m,xlabels,ylabels):
    norm = MidpointNormalize(midpoint=0)
    ax.set_aspect('equal')
    plt.xticks(rotation=90)    
    ax.set_xticks(np.arange(m.shape[1])+0.5, minor=False)
    ax.set_yticks(np.arange(m.shape[0])+0.5, minor=False)
    ax.set_xticklabels(xlabels, minor=False)
    ax.set_yticklabels(ylabels, minor=False)
    for tic in ax.xaxis.get_major_ticks():
        tic.tick1On = tic.tick2On = False
    for tic in ax.yaxis.get_major_ticks():
        tic.tick1On = tic.tick2On = False
    #ax.set_frame_on(False)
    heatmap = plt.pcolor(np.array(m), norm=norm, cmap=mpl.cm.RdBu, edgecolors="black")    
    #im = ax.imshow(np.array(m), norm=norm, cmap=plt.cm.seismic, interpolation='none')
#fig.colorbar(im)
    plt.colorbar(heatmap,orientation='horizontal')
    
def draw_features_and_similarity(mm,numbered=False):
    rows,cols,xlabels=mm.filter_submatrix(words_of_interest)
    ax=plt.subplot(1,2,1)
    plot_heat(ax,cols,xlabels,words_of_interest)
    #plot_heat(ax,abs(m),numbered)
    ax=plt.subplot(1,2,2)
    t = 1-pairwise_distances(rows, metric="cosine")
    np.fill_diagonal(t,0)
    plot_heat(ax,t,words_of_interest,words_of_interest)
    #plt.savefig("m1.pdf")
    #plt.show()

#draw_features_and_similarity(cooccurrence.todense())
#words_of_interest=["day","running","quick","fast","kind","good","point","fun"]
#words_of_interest=["king","man"]
words_of_interest=["apple","banana","orange","pineapple"]
draw_features_and_similarity(m)
plt.savefig("plot.pdf")
#draw_features_and_similarity(dense)

# %%
if cooccurrence.shape[1]>8000:
    print ("No way, this matrix is too huge")
else:
    c=cooccurrence.todense()
    ut, s_ev, vt = np.linalg.svd(c.T,full_matrices=False)
    #projected=np.dot(vt.T,np.diag(s_ev))#[:,[0,1,2,3]]
    projected_densesvd=np.dot(c,ut)
    plt.plot(s_ev)
    plt.show()
    filename=dir_root.split('/')[-1]+"_dense"
    filename=os.path.join("sigmas",filename)
    print (filename)
    with open(filename, 'wb') as f:
        #pickle.dump(s_ev, f)
        #s_ev.tofile(f)
        np.savetxt(f,s_ev)
    draw_features_and_similarity(projected_densesvd,True) 
    plt.show()
   

#print(s_ev)
#type(s_ev)
#projected=vt
#draw_features_and_similarity(projected,True) 
#plt.plot(s_ev)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-27dbee8ca646> in <module>()
# ----> 1 if cooccurrence.shape[1]>8000:
#       2     print ("No way, this matrix is too huge")
#       3 else:
#       4     c=cooccurrence.todense()
#       5     ut, s_ev, vt = np.linalg.svd(c.T,full_matrices=False)
#
# NameError: name 'cooccurrence' is not defined

# %% [markdown]
# #Trying scipy.sparse.linalg.svd

# %%
from scipy import sparse
from scipy.sparse import linalg
cnt_singular_vectors=200

class Model_numbered(model):
    def get_x_label(self,i):
        return i
    def viz_wordlist(self,wl):
        for i in wl:
            row = self.get_row(i)
            row = row / np.linalg.norm(row)
            plt.bar(range(0,len(row)), row, color = "black", linewidth  = 0, alpha = 1/len(wl))
    
class Model_svd_scipy(Model_numbered):
    cnt_singular_vectors=50
    def __init__(self,dense):
        ut, s_ev, vt = sparse.linalg.svds(dense.matrix,k=cnt_singular_vectors,which='LM') # LM SM LA SA BE
        self.matrix = np.dot(ut,np.diag(s_ev))
        self.vocabulary = dense.vocabulary


time_start=time.time()
m_svd_scipy = Model_svd_scipy(m)
time_end = time.time()
print ("took {0:0.2f} seconds".format(time_end-time_start))
# Out:
# took 246.14 seconds

# %%
#plt.plot(s_ev)
#plt.show()
#vt=np.nan_to_num(vt.T)
draw_features_and_similarity(m_svd_scipy,True) 
#plt.show
#None

# %%
#m_svd_scipy.get_most_similar_words("fast")
row1=m_svd_scipy.get_row("smaller")
row2=m_svd_scipy.get_row("small")
row3=m_svd_scipy.get_row("large")
row = row1-row2+row3
m_svd_scipy.get_most_similar_words(row)
# Out:
# [['huge', 0.54803794716234688],
#  ['larger', 0.54206412776510349],
#  ['vast', 0.53225029527620304],
#  ['unfossiliferous', 0.50874613752469511],
#  ['largest', 0.48900361603356934],
#  ['polapan', 0.47527325407699017],
#  ['large', 0.46844838916312947],
#  ['massive', 0.46097128413060418],
#  ['enormous', 0.43905660076841146],
#  ['bigger', 0.43768323834506528]]

# %% [markdown]
# #Trying sparsescd

# %%
from sparsesvd import sparsesvd
c=cooccurrence.T.tocsc()
time_start = time.time()
ut, s_ev, vt = sparsesvd(c,cnt_singular_vectors)
projected_svdpack=np.dot(vt.T,np.diag(s_ev))
time_end = time.time()
print ("took {0:0.2f} seconds".format(time_end-time_start))
draw_features_and_similarity(projected_svdpack,True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-87b05fc44b9a> in <module>()
#       1 from sparsesvd import sparsesvd
# ----> 2 c=cooccurrence.T.tocsc()
#       3 time_start = time.time()
#       4 ut, s_ev, vt = sparsesvd(c,cnt_singular_vectors)
#       5 projected_svdpack=np.dot(vt.T,np.diag(s_ev))
#
# NameError: name 'cooccurrence' is not defined

# %%
plt.plot(s_ev)

# %%
################## MPLD3    ############################
#import mpld3
#mpld3.enable_notebook()
#fig, ax = plt.subplots()
#np.random.seed(0)
#ax.plot(np.random.normal(size=100),
#        np.random.normal(size=100),
#        'or', ms=10, alpha=0.3)
#ax.plot(np.random.normal(size=100),
#        np.random.normal(size=100),
#        'ob', ms=20, alpha=0.1)

#ax.set_xlabel('this is x')
#ax.set_ylabel('this is y')
#ax.set_title('Matplotlib Plot Rendered in D3!', size=14)
#ax.grid(color='lightgray', alpha=0.7)

#mpld3.display(fig)

# %%
################## TRY BOKEH ###############
#import bokeh
#import bokeh.plotting
#bokeh.plotting.output_notebook()

# %%
#bokeh.plotting.rect(list(range(8)),list(range(8)), 0.95, 0.95, # source=c,
     #x_axis_location="above",
     #x_range=years, y_range=list(reversed(months)),
     #color='color', 
#     line_color=None,
#     tools="resize,hover", 
#     title="Co-occurrence matrix",
#     plot_width=400, plot_height=400)
#bokeh.plotting.grid().grid_line_color = None
#bokeh.plotting.axis().axis_line_color = None
#bokeh.plotting.axis().major_tick_line_color = None
#bokeh.plotting.axis().major_label_text_font_size = "6pt"
#bokeh.plotting.axis().major_label_standoff = 0
#bokeh.plotting.xaxis().major_label_orientation = np.pi/3
#bokeh.plotting.show()

# %%
def cmp_first_tail(l,verbose=False):
    max_score=-1;
    max_element=None
    scores=[]
    if verbose: 
        print (l[0]," vs")
    for i in l[1:]:
        score=cmp_words(l[0],i)
        scores.append(score)
        if verbose: print (i.ljust(10)+"\t"+str(score))
    confidence = sorted(scores)[-1]-sorted(scores)[-2]
    return scores,  l[scores.index(max(scores))+1]
    #return l[scores.index(max(scores))+1], confidence

# %%
def get_most_related_rows(id,m):
    scores=[]
    if id<0: return []
    for i in range(m.shape[0]):
        if i==id: continue
        scores.append([similarity.cmp_rows(id,i,m),i])
    scores.sort()
    result=[]
    for q in reversed(scores[-10:]):
        if q[0]>0:
            result.append([q[1],q[0]])
    return result

def get_most_related_words(word,m,dic_words,lst_words):
    id = dic_words[word]
    rows = get_most_related_rows(id,m)
    results=[]
    for i in rows:
        results.append([lst_words[i[0]],i[1]])
    return results

#cmp_first_tail(["run","walk","fast","day","foo1"])

#%timeit -n 1 get_most_related_words("fast")
#get_most_related_words("fuck",matr)
#get_most_related_words("fuck",matr,dic_words,lst_words_w2v)
vec=matr[dic_words["bigger"]]-matr[dic_words["big"]]+matr[dic_words["small"]]
#vec=matr[dic_words["paris"]]-matr[dic_words["france"]]+matr[dic_words["russia"]]
#vec=matr[dic_words["zero"]]
get_most_similar_words(vec,matr,lst_words_w2v)
#get_word_by_id(1)
#get_id("gutenberg-tm")
# Out:
# [['larger', 0.79604118543555413],
#  ['smaller', 0.77799100774718188],
#  ['small', 0.75163052328762969],
#  ['large', 0.70140707324434004],
#  ['lower', 0.54960576786158666],
#  ['greater', 0.53035088176120104],
#  ['bigger', 0.52275781641987906],
#  ['narrower', 0.51627845958656615],
#  ['thinner', 0.50695944543631422],
#  ['thicker', 0.50139409801595369]]

# %%
def do_synonyms_test(lines):
    output=""
    cnt_all=0;
    cnt_correct=0;
    lst_conf=[]
    for tokens in lines:
        print ("processing",tokens[0])
        #guess,confidence=cmp_first_tail(tokens[:-1],verbose=False)
        scores,guess=cmp_first_tail(tokens[:-1],verbose=False)
        #print (scores)
        if guess==tokens[-1]:
            cnt_correct+=1
            #lst_conf.append(confidence)
        cnt_all+=1
        #print (tokens[0],guess,guess==tokens[-1],"\n")
        output+="<b>"+tokens[0]+"</b>[{}] : ".format(get_frequency(get_id(tokens[0])))

        for i in range(len(tokens)-2):
            t=tokens[i+1]
            if t==guess:
                if (t==tokens[-1]):
                    output+=" <span style=\"color:green;\">"+t+"</span>"
                else:
                    output+=" <span style=\"color:red;\">"+t+"</span>"
            else: 
                if (t==tokens[-1]):
                    output+=" <span style=\"text-decoration: underline; border-decoration-color: green; -moz-text-decoration-color: green;\">"+t+"</span>"
                else:
                    output+=" "+t
            output+="[{}]".format(get_frequency(get_id(t)))
            output+="({:.2f})".format(scores[i])
        output+="<br />\n"
        #related=get_most_related_words(tokens[0])
        #for r in related:
#            output+="{}({:.2f}) ".format(r[0],r[1])
        #if (guess==tokens[-1]):
#            output+="<span style=\"color:green\">correct!</span>"
#        else:
#            output+="<span style=\"color:red\">wrong</span>, should be "+tokens[-1]
        #output+="<br /><br />\n"
    success_rate=cnt_correct/cnt_all
    output+="<br />success rate = " + str( success_rate)+"</br>\n"
    #output+="avg confidence = "+ str( np.mean(lst_conf))+"</br>\n"
    with open("last_test.html", 'w') as f:
        print(output,file=f)
    #s_ev.tofile(f)
    return HTML(output)
#do_synonyms_test(testhelper.get_test_from_toefl("../tests/toefl/toefl"))

# %%
#do_synonyms_test(get_test_from_file("../tests/syn_easy.txt"))
#do_synonyms_test(testhelper.get_test_from_toefl("../tests/toefl/toefl"))

# %%
#print (get_pmi("sufficient"))
#print (get_pmi("fearing"))
#cmp_words("sufficient","fearing")

# %%
lst_sigmas=[]
legends=[]
for filename in glob.glob("./sigmas/*"):
    f=open(filename,"r")
    sigmas = np.loadtxt(f)
    lst_sigmas.append(sigmas)
    plt.plot(sigmas,label="test")
    legends.append(filename.split("/")[-1])
    f.close()
plt.legend(legends)
#print (lst_sigmas)
#plt.plot(x=range(8),y=lst_sigmas)

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %install_default_config  %install_ext  %install_profiles  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%debug  %%file  %%html  %%javascript  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
#l = [i[0] for i in testhelper.get_test_from_toefl("../tests/toefl/toefl")]
#for i in l:
    #print (i)

# %%
class Vocab_w2v(Vocabulary):
    def __init__(self):
        self.dic_words_ids={}
        self.lst_words=[]
        
class model_w2v(Model_numbered):
    def load_word(f):
        result=b''
        w=b''
        while w!=b' ':
            w = f.read(1)
            result=result+w
        return result[:-1]
    def __init__(self,filename):
        self.vocabulary = Vocab_w2v()
        f=  open(filename,"rb")
        header = f.readline().split()
        cnt_rows=int(header[0])
        size_row=int(header[1])
        self.matrix = np.zeros((cnt_rows,size_row),dtype=np.float32)
        print ("cnt rows = {}, size row = {}".format(cnt_rows,size_row))
        for i in range(cnt_rows):
            word = model_w2v.load_word(f).decode('ascii',errors="replace").strip()
            #print (word)
            self.vocabulary.dic_words_ids[word]=i;
            self.vocabulary.lst_words.append(word)
            s_row = f.read(size_row*4)
            row = np.fromstring(s_row, dtype=np.float32)
            #row = row / np.linalg.norm(row)
            self.matrix[i]=row
        f.close()
        
m_w2v = model_w2v("/mnt/work/nlp_scratch/_w2v/vectors.bin")
# Out:
# cnt rows = 71291, size row = 200

# %%
#m_w2v.get_most_similar_words("best")
#bstr.decode('ascii')
draw_features_and_similarity(m_w2v,True)

# %%
mpl.rcParams['figure.figsize'] = (18.0, 8.0)
#row1 = matr[dic_words["king"]]
#row2 = matr[dic_words["emperor"]]
#row3 = matr[dic_words["queen"]]
wordlist = ["apple","banana","kiwi","orange","tomato","cherry","pineapple"]
wordlist2 = ["king","man","soldier","boss","president","policeman"]
#m_w2v.viz_wordlist(wordlist)
m_svd_scipy.viz_wordlist(wordlist)
plt.show()
viz_wordlist(wordlist)
plt.show()

# %%
#wordlist = ["apple","king","zero","france","car","circle","run","hot","myself"]
#viz_wordlist(wordlist2)
#wordlist = [i*2 for i in range(10)]
wordlist = [random.choice(m_w2v.vocabulary.lst_words) for i in range(500)]
#print(wordlist)
m_w2v.viz_wordlist(wordlist2)

plt.show()
